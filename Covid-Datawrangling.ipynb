# %%
from pathlib import Path

import requests
import numpy as np
import pandas as pd
import pandas_profiling
from pandas_profiling.utils.cache import cache_file

# %%
file_name = cache_file(
    "COVID-19 Cases-1",
    "https://prsindia.org/covid-19/cases/download",
)
    
df = pd.read_csv(file_name)

# %%
df.head()
# Out:
#    S. No.        Date Region  Confirmed Cases  Active Cases  Cured/Discharged  \
# 0       1  12/03/2020  India               74            71               3.0
# 1       2  13/03/2020  India               75            71               3.0
# 2       3  14/03/2020  India               84            72              10.0
# 3       4  15/03/2020  India              107            95              10.0
# 4       5  16/03/2020  India              114            99              13.0
#
#    Death
# 0    0.0
# 1    1.0
# 2    2.0
# 3    2.0
# 4    2.0

# %%
df.columns
# Out:
# Index(['S. No.', 'Date', 'Region', 'Confirmed Cases', 'Active Cases',
#        'Cured/Discharged', 'Death'],
#       dtype='object')

# %%
df[df['Date']=='14/08/2020']
# Out:
#       S. No.        Date                                    Region  \
# 155      156  14/08/2020                                     India
# 296      297  14/08/2020               Andaman and Nicobar Islands
# 452      453  14/08/2020                            Andhra Pradesh
# 586      587  14/08/2020                         Arunachal Pradesh
# 721      722  14/08/2020                                     Assam
# 867      868  14/08/2020                                     Bihar
# 1016    1017  14/08/2020                                Chandigarh
# 1164    1165  14/08/2020                              Chhattisgarh
# 1262    1263  14/08/2020  Dadra and Nagar Haveli and Daman and Diu
# 1418    1419  14/08/2020                                     Delhi
# 1560    1561  14/08/2020                                       Goa
# 1708    1709  14/08/2020                                   Gujarat
# 1864    1865  14/08/2020                                   Haryana
# ...

# %%
df1=pd.read_csv(r'C:\Users\lalit\Desktop\lalpy\COVID\Kaggle\population_india_census2011.csv')

# %%
df1.columns
# Out:
# Index(['Sno', 'State / Union Territory', 'Population', 'Rural population',
#        'Urban population', 'Area', 'Density', 'Gender Ratio'],
#       dtype='object')

# %%
dfm=pd.merge(df, df1, how='inner', on=None, left_on='Region', right_on='State / Union Territory',
         left_index=False, right_index=False, sort=True,
         suffixes=('x', 'y'), copy=True, indicator=False,
         validate=None)

# %%
dfm[dfm['Date']=='14/08/2020']
# Out:
#       S. No.        Date                                    Region  \
# 140      297  14/08/2020               Andaman and Nicobar Islands
# 296      453  14/08/2020                            Andhra Pradesh
# 430      587  14/08/2020                         Arunachal Pradesh
# 565      722  14/08/2020                                     Assam
# 711      868  14/08/2020                                     Bihar
# 860     1017  14/08/2020                                Chandigarh
# 1008    1165  14/08/2020                              Chhattisgarh
# 1106    1263  14/08/2020  Dadra and Nagar Haveli and Daman and Diu
# 1262    1419  14/08/2020                                     Delhi
# 1404    1561  14/08/2020                                       Goa
# 1552    1709  14/08/2020                                   Gujarat
# 1708    1865  14/08/2020                                   Haryana
# 1855    2012  14/08/2020                          Himachal Pradesh
# ...

# %%
dfm=dfm.drop(['Sno','S. No.','State / Union Territory','Area','Density'],axis=1)

# %%
dfm[dfm['Date']=='14/08/2020']
# Out:
#             Date                                    Region  Confirmed Cases  \
# 140   14/08/2020               Andaman and Nicobar Islands             2037
# 296   14/08/2020                            Andhra Pradesh           264142
# 430   14/08/2020                         Arunachal Pradesh             2512
# 565   14/08/2020                                     Assam            71795
# 711   14/08/2020                                     Bihar            94193
# 860   14/08/2020                                Chandigarh             1842
# 1008  14/08/2020                              Chhattisgarh            13937
# 1106  14/08/2020  Dadra and Nagar Haveli and Daman and Diu             1752
# 1262  14/08/2020                                     Delhi           149460
# 1404  14/08/2020                                       Goa            10494
# 1552  14/08/2020                                   Gujarat            75408
# ...
